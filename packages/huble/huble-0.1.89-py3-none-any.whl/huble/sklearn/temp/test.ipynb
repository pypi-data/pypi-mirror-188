# %%
from huble.sklearn.process.generate import convert_graph,generate_script,generate_steps

# %%
test = """{"nodes":[{"id":"999","type":"custom","position":{"x":-79.23851679596174,"y":169.53800088480847},"data":{"name":"titanic.csv","value":"QmRspeqXi9J2PVTmXYwMaBif9dYWVkNhM8EFomUAfajnT1","color":"pink.400","isInput":true,"parameters":{},"outputParameters":{"types":["Dataframe"],"isCustomizable":false},"node_type":"primary_dataset"},"width":240,"height":101,"selected":false,"positionAbsolute":{"x":-79.23851679596174,"y":169.53800088480847},"dragging":false,"target":"1"},{"id":"998","type":"custom","position":{"x":1697.148949978258,"y":643.9636163439158},"data":{"name":"Evaluate Model","value":"Evaluate Model","color":"green.400","isOutput":true,"parameters":{},"inputParameters":{"types":["Testing Dataset","Trained Model"],"isCustomizable":false},"node_type":"evaluate_model"},"width":240,"height":129,"selected":true,"positionAbsolute":{"x":1697.148949978258,"y":643.9636163439158},"dragging":false,"source":"6"},{"id":"1","type":"custom","position":{"x":186.09437031982708,"y":320.48692578983844},"data":{"name":"Dropping rows or columns","value":"Dropping rows or columns","parameters":{"labels":[{"value":"PassengerId","label":"PassengerId"},{"value":"Name","label":"Name"}],"axis":0,"inplace":false,"errors":"raise"},"inputParameters":{"types":["Dataframe"],"isCustomizable":false},"outputParameters":{"types":["Dataframe"],"isCustomizable":false},"node_type":"preprocess"},"width":254,"height":154,"selected":false,"positionAbsolute":{"x":186.09437031982708,"y":320.48692578983844},"dragging":false,"source":"999","target":"2"},{"id":"2","type":"custom","position":{"x":479.5889787269383,"y":334.768852212166},"data":{"name":"Remove Outliers","value":"Remove Outliers","parameters":{"columns":[{"value":"Ticket","label":"Ticket"}]},"inputParameters":{"types":["Dataframe"],"isCustomizable":false},"outputParameters":{"types":["Dataframe"],"isCustomizable":false},"node_type":"preprocess"},"width":240,"height":135,"selected":false,"positionAbsolute":{"x":479.5889787269383,"y":334.768852212166},"dragging":false,"source":"1","target":"4"},{"id":"4","type":"custom","position":{"x":793.3012278708791,"y":379.9545448567504},"data":{"name":"Clean Column Names","value":"Clean Column Names","parameters":{},"inputParameters":{"types":["Dataframe"],"isCustomizable":false},"outputParameters":{"types":["Dataframe"],"isCustomizable":false},"node_type":"preprocess"},"width":240,"height":135,"selected":false,"positionAbsolute":{"x":793.3012278708791,"y":379.9545448567504},"dragging":false,"source":"2","target":"6"},{"id":"5","type":"custom","position":{"x":1374.0407677138387,"y":751.12661758235},"data":{"name":"Train Model","value":"Train Model","parameters":{},"inputParameters":{"types":["Training Dataset","Model"],"isCustomizable":false},"outputParameters":{"types":["Trained Model"],"isCustomizable":false},"node_type":"essential"},"width":240,"height":158,"selected":false,"positionAbsolute":{"x":1374.0407677138387,"y":751.12661758235},"dragging":false,"source":"7","target":"998"},{"id":"6","type":"custom","position":{"x":1083.6140812307149,"y":559.928669377091},"data":{"name":"Train-Test Split","value":"Train-Test Split","parameters":{},"inputParameters":{"types":["Dataframe"],"isCustomizable":false},"outputParameters":{"types":["Testing Dataset","Training Dataset"],"isCustomizable":false},"node_type":"essential"},"width":240,"height":158,"selected":false,"positionAbsolute":{"x":1083.6140812307149,"y":559.928669377091},"dragging":false,"source":"4","target":"998"},{"id":"7","type":"custom","position":{"x":988.2563113735717,"y":748.864153587452},"data":{"name":"Random Forest Classifier","value":"Random Forest Classifier","parameters":{"n_estimators":100,"max_depth":5,"max_features":"auto","criterion":"gini"},"outputParameters":{"types":["Model"],"isCustomizable":false},"node_type":"model"},"width":242,"height":124,"selected":false,"positionAbsolute":{"x":988.2563113735717,"y":748.864153587452},"dragging":false,"target":"5"}],"edges":[{"source":"999","sourceHandle":"output_0_Dataframe","target":"1","targetHandle":"input_0_Dataframe","type":"custom","data":{"sourceColor":"pink.400","targetColor":"#805AD5","target":"1_input_0_Dataframe","source":"999_output_0_Dataframe"},"id":"reactflow__edge-999output_0_Dataframe-1input_0_Dataframe"},{"source":"1","sourceHandle":"output_0_Dataframe","target":"2","targetHandle":"input_0_Dataframe","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"#805AD5","target":"2_input_0_Dataframe","source":"1_output_0_Dataframe"},"id":"reactflow__edge-1output_0_Dataframe-2input_0_Dataframe"},{"source":"2","sourceHandle":"output_0_Dataframe","target":"4","targetHandle":"input_0_Dataframe","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"#805AD5","target":"4_input_0_Dataframe","source":"2_output_0_Dataframe"},"id":"reactflow__edge-2output_0_Dataframe-4input_0_Dataframe"},{"source":"4","sourceHandle":"output_0_Dataframe","target":"6","targetHandle":"input_0_Dataframe","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"#805AD5","target":"6_input_0_Dataframe","source":"4_output_0_Dataframe"},"id":"reactflow__edge-4output_0_Dataframe-6input_0_Dataframe"},{"source":"6","sourceHandle":"output_1_Training Dataset","target":"5","targetHandle":"input_0_Training Dataset","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"#805AD5","target":"5_input_0_Training Dataset","source":"6_output_1_Training Dataset"},"id":"reactflow__edge-6output_1_Training Dataset-5input_0_Training Dataset"},{"source":"7","sourceHandle":"output_0_Model","target":"5","targetHandle":"input_1_Model","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"#805AD5","target":"5_input_1_Model","source":"7_output_0_Model"},"id":"reactflow__edge-7output_0_Model-5input_1_Model"},{"source":"5","sourceHandle":"output_0_Trained Model","target":"998","targetHandle":"input_1_Trained Model","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"green.400","target":"998_input_1_Trained Model","source":"5_output_0_Trained Model"},"id":"reactflow__edge-5output_0_Trained Model-998input_1_Trained Model"},{"source":"6","sourceHandle":"output_0_Testing Dataset","target":"998","targetHandle":"input_0_Testing Dataset","type":"custom","data":{"sourceColor":"#805AD5","targetColor":"green.400","target":"998_input_0_Testing Dataset","source":"6_output_0_Testing Dataset"},"id":"reactflow__edge-6output_0_Testing Dataset-998input_0_Testing Dataset"}]}"""

# %%
import json
graph = json.loads(test)
graph
# Out:
# {'nodes': [{'id': '999',
#    'type': 'custom',
#    'position': {'x': -79.23851679596174, 'y': 169.53800088480847},
#    'data': {'name': 'titanic.csv',
#     'value': 'QmRspeqXi9J2PVTmXYwMaBif9dYWVkNhM8EFomUAfajnT1',
#     'color': 'pink.400',
#     'isInput': True,
#     'parameters': {},
#     'outputParameters': {'types': ['Dataframe'], 'isCustomizable': False},
#     'node_type': 'primary_dataset'},
#    'width': 240,
#    'height': 101,
#    'selected': False,
#    'positionAbsolute': {'x': -79.23851679596174, 'y': 169.53800088480847},
#    'dragging': False,
#    'target': '1'},
#   {'id': '998',
#    'type': 'custom',
#    'position': {'x': 1697.148949978258, 'y': 643.9636163439158},
#    'data': {'name': 'Evaluate Model',
#     'value': 'Evaluate Model',
#     'color': 'green.400',
#     'isOutput': True,
#     'parameters': {},
#     'inputParameters': {'types': ['Testing Dataset', 'Trained Model'],
#      'isCustomizable': False},
#     'node_type': 'evaluate_model'},
# ...

# %%
generate_script(graph)
# Out:
# ['Dropping rows or columns', 'Remove Outliers', 'Clean Column Names']
# "\ndata = huble.sklearn.drop_rows_columns(data=data,parameters={'labels': ['PassengerId', 'Name'], 'axis': 0, 'inplace': False, 'errors': 'raise'})\n\ndata = huble.sklearn.remove_outliers(data=data,columns=['Ticket'])\n\nNone\n\nNone\n"

# %%
import pandas as pd
import requests


def load_dataset(url) -> pd.DataFrame:
    local_filename = "test.csv"  # url.split('/')[-1]
    # NOTE the stream=True parameter below
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, "wb") as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)
    return pd.read_csv(local_filename)

# %%
import huble

data = load_dataset("https://ipfs.filebase.io/ipfs/QmRspeqXi9J2PVTmXYwMaBif9dYWVkNhM8EFomUAfajnT1")
#data.info()
data = huble.sklearn.remove_nan_values(data=data, parameters={ "how": "all", "inplace": False})
data.info()
# data = huble.sklearn.drop_rows_columns(
#     data=data,
#     parameters={
#         "labels": ["Sex", "Pclass", "Parch"],
#         "axis": 1,
#         "inplace": False,
#         "errors": "raise",
#     },
# )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
