# %%
import os, sys, math
from datetime import timedelta # only needed if datetime is used, might be able to be removed
from pathlib import Path, PurePath


import pandas as pd
from pandas import DataFrame
# SOS Package imports
from process_road_objects import * # !{sys.executable} -m pip install PACKAGE_NAME OR !pip3 install transformers
import dro
import dod as Driver
from dro import Vehicle
#from DynamicObjectDriver import Driver
from ProcessVideo import *

# %% [markdown]
# ### File Path Setup and GPX

# %%
# "P-CA.1_NB_run_2022-09-08_07-23-47"  # "K1.2022-10-05_105104_Walnut_Creek" P-YVR.3-EB-2022-09-01_07-31-27
# P-CA.2_SB_run_2022-09-08_07-29-25
# P-YVR.3-EB-2022-09-01_07-31-27
# P-YVR-EB_run_2022-09-17_16-16-05
# I1.2022-09-07_094806_Walnut_Creek
# K1.2022-10-05_105104_Walnut_Creek
# P-YVR.2-WB-2022-09-01_07-17-54.gpx - YVR WB - Best Run


# Initilize DataFrames for Intersection
process_ro = ProcessRoadObjects()

# Setup CSV Input File paths
intersection_csv_file_name = "WCIntersections-2022-05-28"  # exclude .csv
all_intersections = process_ro.load_intersection_csv(intersection_csv_file_name)

# Setup GPX files
gpx_filename = "P-YVR.2-WB-2022-09-01_07-17-54" 
# TODO: Try 1.0, if error: Except 1.1 ver.
gpx_ver = "1.1"
gpx_df2 = process_ro.load_gpx_to_obj_df(gpx_filename, gpx_ver)

process_ro.gpx_summary()

sd_out = process_ro.intersection_sight_distance_timestamps()
# Out:
# Processed 101 lines of CSV file for a total of 101 intersections.
# Using GPX file: in/gpx_video/P-YVR.2-WB-2022-09-01_07-17-54.gpx.gpx
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 21
#      19 # TODO: Try 1.0, if error: Except 1.1 ver.
#      20 gpx_ver = "1.1"
# ---> 21 gpx_df2 = process_ro.load_gpx_to_obj_df(gpx_filename, gpx_ver)
#      23 process_ro.gpx_summary()
#      25 sd_out = process_ro.intersection_sight_distance_timestamps()
#
# File ~/Documents/Projects/Traffic Signal Sight Distance Checks/RODC/process_road_objects.py:180, in ProcessRoadObjects.load_gpx_to_obj_df(self, gpx_filename, gpx_ver, use_pickle)
#     175 else:
#     176     print(
#     177         f"Using GPX file: {self.gpx_file}"
#     178     )
# --> 180 gpx_file_ref = open(self.gpx_file, "r")
#     181 # use GPX v1.0, assume speed data otherwise will calculate
#     182 # if speed is captured in GPX v1.1 as extension data, change version to 1.1
#     183 # TODO: set timezone with lat, lon coordinate (https://stackoverflow.com/questions/15742045/getting-time-zone-from-lat-long-coordinates)
#     184 gpx = gpxpy.parse(gpx_file_ref, version=self.gpx_ver)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'in/gpx_video/P-YVR.2-WB-2022-09-01_07-17-54.gpx.gpx'

# %% [markdown]
# Which Frame in the video best cooresponds to a gpx point in the gpx track.
#
# look for a gpx point that is well situated with the markings on the ground to find that frame.
#
# Need that frame #, and which point in gpx file it cooresponds to.
#
#
# 1662646906.90500

# %% [markdown]
# ### Filter GPX to Locations of interest

# %%
# Setup video files


video_filename = "K1.IMG_0062.MOV"
# K1.IMG_0062.MOV
# P-CA.1_CAL Before AM Run 1 & 2.MP4
# P-YVR.3-Before AM EB Run 3.MP4
# P-YVR WKD PM R1 and R2 EB.MOV


video = ProcessVideo(video_filename)
# video.sync(video_frame, timestamp) to calculate start of video in utc.
video.sync(27045, "2022-10-05T18:12:29.072Z")
video.vid_summary()

#filenames, frames = video.create_pic_list_from_zip(sd_out)
#print(frames)


#video.extract_frame(frames, filenames)
# Out:
#                 ===================================VIDEO SUMMARY===================================
#                 # Video File: in/gpx_video/K1.IMG_0062.MOV#/K1.IMG_0062.MOV
#                 # Video File Size: 7.9 GB
#                 # Resolution (w x h): 3840.0 x 2160.0 (8.3MP)
#                 # Frames Per Second: 59.99389153104411
#                 # Total Number of Frames: 75625.0
#                 # Total Duration: 21:0.55 (MM:SS.ss)
#                 # Start Time: 2022-10-05 11:04:58.276105
#                 # End Time:   2022-10-05 11:25:58.821105
#                 ===================================================================================

# %%
video.img_overlay_info_box(video_filename, process_ro)
# Out:
# 12.2-Walnut Ave-Bancroft Rd+Ygnacio Valley Rd-390-1664994020.51.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.0/4.0
# SB approach of Walnut Ave-Bancroft Rd and Ygnacio Valley Rd (#12) at ~390 ft on 2022-10-05 11:20:20.510000 -3.9-Text_x,y:3753,36
# 73.0-Bancroft Rd+Pomar Way-390-1664993526.79.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Pomar Way (#73) at ~390 ft on 2022-10-05 11:12:06.790000 -4.700000000000001-Text_x,y:3784,43
# 66.0-Bancroft Rd+Treat Bl-390-1664993542.904.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# NB approach of Bancroft Rd and Treat Bl (#66) at ~390 ft on 2022-10-05 11:12:22.904000 -4.9-Text_x,y:3833,45
# 76.2-Bancroft Rd+Banbury-390-1664993970.08.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# SB approach of Bancroft Rd and Banbury (#76) at ~390 ft on 2022-10-05 11:19:30.080000 -4.9-Text_x,y:3833,45
# 75.0-Bancroft Rd+Canal Trail-390-1664993852.12.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Canal Trail (#75) at ~390 ft on 2022-10-05 11:17:32.120000 -4.700000000000001-Text_x,y:3766,43
# 8.1-Tampico-Marchbanks Dr+Ygnacio Valley Rd-390-1664993268.993.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.1000000000000005/4.1000000000000005
# EB approach of Tampico-Marchbanks Dr and Ygnacio Valley Rd (#8) at ~390 ft on 2022-10-05 11:07:48.993000 -4.000000000000001-Text_x,y:3805,37
# 73.3-Bancroft Rd+Pomar Way-215-1664993906.956.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# WB approach of Bancroft Rd and Pomar Way (#73) at ~215 ft on 2022-10-05 11:18:26.956000 -4.700000000000001-Text_x,y:3794,43
# 85.3-Walnut Ave+Blackstone-215-1664994277.288.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.9/4.9
# WB approach of Walnut Ave and Blackstone (#85) at ~215 ft on 2022-10-05 11:24:37.288000 -4.800000000000001-Text_x,y:3812,44
# 76.2-Bancroft Rd+Banbury-390-1664993788.33.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# SB approach of Bancroft Rd and Banbury (#76) at ~390 ft on 2022-10-05 11:16:28.330000 -4.9-Text_x,y:3833,45
# 76.0-Bancroft Rd+Banbury-390-1664993489.413.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# NB approach of Bancroft Rd and Banbury (#76) at ~390 ft on 2022-10-05 11:11:29.413000 -4.9-Text_x,y:3833,45
# 12.1-Walnut Ave-Bancroft Rd+Ygnacio Valley Rd-390-1664993429.512.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.0/4.0
# EB approach of Walnut Ave-Bancroft Rd and Ygnacio Valley Rd (#12) at ~390 ft on 2022-10-05 11:10:29.512000 -3.9-Text_x,y:3753,36
# 86.2-Walnut Ave+Wiget-325-1664994330.245.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.2/5.2
# SB approach of Walnut Ave and Wiget (#86) at ~325 ft on 2022-10-05 11:25:30.245000 -5.1000000000000005-Text_x,y:3811,47
# 11.1-San Carlos Dr+Ygnacio Valley Rd-390-1664993348.88.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.4/4.4
# EB approach of San Carlos Dr and Ygnacio Valley Rd (#11) at ~390 ft on 2022-10-05 11:09:08.880000 -4.300000000000001-Text_x,y:3759,40
# 10.1-John Muir Hospital+Ygnacio Valley Rd-390-1664993323.266.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.3/4.3
# EB approach of John Muir Hospital and Ygnacio Valley Rd (#10) at ~390 ft on 2022-10-05 11:08:43.266000 -4.2-Text_x,y:3827,39
# 75.2-Bancroft Rd+Canal Trail-390-1664993757.151.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# SB approach of Bancroft Rd and Canal Trail (#75) at ~390 ft on 2022-10-05 11:15:57.151000 -4.700000000000001-Text_x,y:3766,43
# 73.0-Bancroft Rd+Pomar Way-390-1664993862.622.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Pomar Way (#73) at ~390 ft on 2022-10-05 11:17:42.622000 -4.700000000000001-Text_x,y:3784,43
# 101.0-Bancroft Rd+Minert-390-1664993648.255.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# NB approach of Bancroft Rd and Minert (#101) at ~390 ft on 2022-10-05 11:14:08.255000 -4.9-Text_x,y:3808,45
# 74.0-Bancroft Rd+David-390-1664993644.929.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.1000000000000005/5.1000000000000005
# NB approach of Bancroft Rd and David (#74) at ~390 ft on 2022-10-05 11:14:04.929000 -5.000000000000001-Text_x,y:3781,46
# 85.2-Walnut Ave+Blackstone-325-1664994181.387.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.9/4.9
# SB approach of Walnut Ave and Blackstone (#85) at ~325 ft on 2022-10-05 11:23:01.387000 -4.800000000000001-Text_x,y:3803,44
# 9.1-La Casa Via-Kinross+Ygnacio Valley Rd-390-1664993285.61.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.2/4.2
# EB approach of La Casa Via-Kinross and Ygnacio Valley Rd (#9) at ~390 ft on 2022-10-05 11:08:05.610000 -4.1000000000000005-Text_x,y:3761,38
# 85.1-Walnut Ave+Blackstone-215-1664994234.574.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.9/4.9
# EB approach of Walnut Ave and Blackstone (#85) at ~215 ft on 2022-10-05 11:23:54.574000 -4.800000000000001-Text_x,y:3803,44
# 66.2-Bancroft Rd+Treat Bl-390-1664993736.218.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# SB approach of Bancroft Rd and Treat Bl (#66) at ~390 ft on 2022-10-05 11:15:36.218000 -4.9-Text_x,y:3833,45
# 74.2-Bancroft Rd+David-390-1664993676.618.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.1000000000000005/5.1000000000000005
# SB approach of Bancroft Rd and David (#74) at ~390 ft on 2022-10-05 11:14:36.618000 -5.000000000000001-Text_x,y:3781,46
# 75.0-Bancroft Rd+Canal Trail-390-1664993516.337.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Canal Trail (#75) at ~390 ft on 2022-10-05 11:11:56.337000 -4.700000000000001-Text_x,y:3766,43
# 73.2-Bancroft Rd+Pomar Way-390-1664993748.95.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# SB approach of Bancroft Rd and Pomar Way (#73) at ~390 ft on 2022-10-05 11:15:48.950000 -4.700000000000001-Text_x,y:3784,43
# 12.2-Walnut Ave-Bancroft Rd+Ygnacio Valley Rd-390-1664994020.51.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.0/4.0
# SB approach of Walnut Ave-Bancroft Rd and Ygnacio Valley Rd (#12) at ~390 ft on 2022-10-05 11:20:20.510000 -3.9-Text_x,y:3753,36
# 73.0-Bancroft Rd+Pomar Way-390-1664993526.79.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Pomar Way (#73) at ~390 ft on 2022-10-05 11:12:06.790000 -4.700000000000001-Text_x,y:3784,43
# 66.0-Bancroft Rd+Treat Bl-390-1664993542.904.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# NB approach of Bancroft Rd and Treat Bl (#66) at ~390 ft on 2022-10-05 11:12:22.904000 -4.9-Text_x,y:3833,45
# 76.2-Bancroft Rd+Banbury-390-1664993970.08.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# SB approach of Bancroft Rd and Banbury (#76) at ~390 ft on 2022-10-05 11:19:30.080000 -4.9-Text_x,y:3833,45
# 75.0-Bancroft Rd+Canal Trail-390-1664993852.12.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Canal Trail (#75) at ~390 ft on 2022-10-05 11:17:32.120000 -4.700000000000001-Text_x,y:3766,43
# 8.1-Tampico-Marchbanks Dr+Ygnacio Valley Rd-390-1664993268.993.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.1000000000000005/4.1000000000000005
# EB approach of Tampico-Marchbanks Dr and Ygnacio Valley Rd (#8) at ~390 ft on 2022-10-05 11:07:48.993000 -4.000000000000001-Text_x,y:3805,37
# 73.3-Bancroft Rd+Pomar Way-215-1664993906.956.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# WB approach of Bancroft Rd and Pomar Way (#73) at ~215 ft on 2022-10-05 11:18:26.956000 -4.700000000000001-Text_x,y:3794,43
# 85.3-Walnut Ave+Blackstone-215-1664994277.288.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.9/4.9
# WB approach of Walnut Ave and Blackstone (#85) at ~215 ft on 2022-10-05 11:24:37.288000 -4.800000000000001-Text_x,y:3812,44
# 76.2-Bancroft Rd+Banbury-390-1664993788.33.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# SB approach of Bancroft Rd and Banbury (#76) at ~390 ft on 2022-10-05 11:16:28.330000 -4.9-Text_x,y:3833,45
# 76.0-Bancroft Rd+Banbury-390-1664993489.413.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# NB approach of Bancroft Rd and Banbury (#76) at ~390 ft on 2022-10-05 11:11:29.413000 -4.9-Text_x,y:3833,45
# 12.1-Walnut Ave-Bancroft Rd+Ygnacio Valley Rd-390-1664993429.512.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.0/4.0
# EB approach of Walnut Ave-Bancroft Rd and Ygnacio Valley Rd (#12) at ~390 ft on 2022-10-05 11:10:29.512000 -3.9-Text_x,y:3753,36
# 86.2-Walnut Ave+Wiget-325-1664994330.245.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.2/5.2
# SB approach of Walnut Ave and Wiget (#86) at ~325 ft on 2022-10-05 11:25:30.245000 -5.1000000000000005-Text_x,y:3811,47
# 11.1-San Carlos Dr+Ygnacio Valley Rd-390-1664993348.88.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.4/4.4
# EB approach of San Carlos Dr and Ygnacio Valley Rd (#11) at ~390 ft on 2022-10-05 11:09:08.880000 -4.300000000000001-Text_x,y:3759,40
# 10.1-John Muir Hospital+Ygnacio Valley Rd-390-1664993323.266.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.3/4.3
# EB approach of John Muir Hospital and Ygnacio Valley Rd (#10) at ~390 ft on 2022-10-05 11:08:43.266000 -4.2-Text_x,y:3827,39
# 75.2-Bancroft Rd+Canal Trail-390-1664993757.151.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# SB approach of Bancroft Rd and Canal Trail (#75) at ~390 ft on 2022-10-05 11:15:57.151000 -4.700000000000001-Text_x,y:3766,43
# 73.0-Bancroft Rd+Pomar Way-390-1664993862.622.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Pomar Way (#73) at ~390 ft on 2022-10-05 11:17:42.622000 -4.700000000000001-Text_x,y:3784,43
# 101.0-Bancroft Rd+Minert-390-1664993648.255.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# NB approach of Bancroft Rd and Minert (#101) at ~390 ft on 2022-10-05 11:14:08.255000 -4.9-Text_x,y:3808,45
# 74.0-Bancroft Rd+David-390-1664993644.929.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.1000000000000005/5.1000000000000005
# NB approach of Bancroft Rd and David (#74) at ~390 ft on 2022-10-05 11:14:04.929000 -5.000000000000001-Text_x,y:3781,46
# 85.2-Walnut Ave+Blackstone-325-1664994181.387.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.9/4.9
# SB approach of Walnut Ave and Blackstone (#85) at ~325 ft on 2022-10-05 11:23:01.387000 -4.800000000000001-Text_x,y:3803,44
# 9.1-La Casa Via-Kinross+Ygnacio Valley Rd-390-1664993285.61.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.2/4.2
# EB approach of La Casa Via-Kinross and Ygnacio Valley Rd (#9) at ~390 ft on 2022-10-05 11:08:05.610000 -4.1000000000000005-Text_x,y:3761,38
# 85.1-Walnut Ave+Blackstone-215-1664994234.574.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.9/4.9
# EB approach of Walnut Ave and Blackstone (#85) at ~215 ft on 2022-10-05 11:23:54.574000 -4.800000000000001-Text_x,y:3803,44
# 66.2-Bancroft Rd+Treat Bl-390-1664993736.218.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.0/5.0
# SB approach of Bancroft Rd and Treat Bl (#66) at ~390 ft on 2022-10-05 11:15:36.218000 -4.9-Text_x,y:3833,45
# 74.2-Bancroft Rd+David-390-1664993676.618.jpg
# (2160, 3840, 3)
# 3840x2160
# 5.1000000000000005/5.1000000000000005
# SB approach of Bancroft Rd and David (#74) at ~390 ft on 2022-10-05 11:14:36.618000 -5.000000000000001-Text_x,y:3781,46
# 75.0-Bancroft Rd+Canal Trail-390-1664993516.337.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# NB approach of Bancroft Rd and Canal Trail (#75) at ~390 ft on 2022-10-05 11:11:56.337000 -4.700000000000001-Text_x,y:3766,43
# 73.2-Bancroft Rd+Pomar Way-390-1664993748.95.jpg
# (2160, 3840, 3)
# 3840x2160
# 4.800000000000001/4.800000000000001
# SB approach of Bancroft Rd and Pomar Way (#73) at ~390 ft on 2022-10-05 11:15:48.950000 -4.700000000000001-Text_x,y:3784,43

# %%
video.extract_frames_between(460, 480, "P-YVR WKD") #X seconds to Y seconds, make directory of video_file_name if not made
#TODO: convert to SS:MM:HH, SS:MM:HH for start and end times

# %%
start_gpx_timestamp = process_ro.get_start_timestamp() 
start_video_timestamp = video.get_start_timestamp()

# TODO: convert to method for quick summary. Start times pretty format, difference in hh:mm:ss, and travel time and length of video and video fps etc.
print(f'GPX Start Time:{start_gpx_timestamp}, Video Start Time:{start_video_timestamp}, difference:{start_video_timestamp-start_gpx_timestamp}')  

# Necessary for both of these?
frames = []
itrsxn_desc = []

filenames, frames = video.create_pic_list_from_zip(sd_out)
print(frames)
#video.extract_frame(frames, itrsxn_desc)

video.extract_frame(frames, filenames)

# %%
#gpx_video_offset = start_video_utc - start_utc_time # >0 when gpx starts before video. Extract frames of video to estimate this value
#print(f'video starts: {gpx_video_offset} seconds after the GPX file')

frames = []
itrsxn_desc = []
print(list(sd_out))
frames , itrsxn_desc = video.create_pic_list_from_zip(sd_out)
video.extract_frame(frames, itrsxn_desc)


#TODO setup loading screen for this.

# %% [markdown]
# ## TODO's
# Frames/Out/approaching intersections_stopbar.csv file needs to append not overwrite
#
#
# HH:MM:SS
#
# and loading bar should be last frame of list, not total duration of video.
#
# picture(s). -saved text
