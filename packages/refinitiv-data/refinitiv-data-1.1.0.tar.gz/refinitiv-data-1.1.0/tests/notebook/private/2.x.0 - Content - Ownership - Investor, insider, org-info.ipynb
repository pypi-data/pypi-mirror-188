# %% [markdown]
# # Refinitiv Data Library for Python
# ## Content - Ownership - Investor, insider, org-info

# %% [markdown]
# This notebook demonstrates how to work with Ownership API db from Refinitiv Data Library.
#
# #### Learn more
#
# To learn more about the Refinitiv Data Libraries just connect to the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [login](https://developers.refinitiv.com/iam/login) to the Refinitiv Developer Community portal you will get free access to a number of learning materials like [Quick Start guides](https://developers.refinitiv.com/refinitiv-data-platform/refinitiv-data-platform-libraries/quick-start), [Tutorials](https://developers.refinitiv.com/refinitiv-data-platform/refinitiv-data-platform-libraries/learning), [Documentation](https://developers.refinitiv.com/refinitiv-data-platform/refinitiv-data-platform-libraries/docs) and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding the API usage, please post them on the [Refinitiv Data Q&A Forum](https://community.developers.thomsonreuters.com/spaces/231/index.html). The Refinitiv Developer Community will be very pleased to help you.

# %% [markdown]
# # Import the library
# Import the library and required modules

# %%
import refinitiv.data as rd
from refinitiv.data.content import ownership

# %% [markdown]
# # Open session
# Create and open a session to connect to the Refinitiv Data via Eikon 4 or the Refinitiv Workspace.

# %%
rd.open_session(name="platform.default")
# Out:
# <refinitiv.data.session._platform_session.Definition object at 0x1b37ce10208 {name='default-session'}>

# %% [markdown]
# # Example

# %% [markdown]
# # Investor

# %% [markdown]
# ## Holdings

# %%
response = ownership.investor.holdings.Definition("TRI.N").get_data()

response.data.df
# Out:
#   instrument      TR.InvtrFullName Total Holdings Count TR.SecurityOwnedRIC  \
# 0      TRI.N  Thomson Reuters Corp                    1               AYX.N
#
#   TR.SecurityOwnedName TR.PctSecuritySharesOut TR.InvestorSharesHeld  \
# 0          Alteryx Inc                       0                     0
#
#   TR.InvestorSharesHeldChg TR.InvestorValueHeld TR.InvestorFilingDate
# 0                        0                    0            2020-12-31

# %% [markdown]
# # Insider

# %% [markdown]
# ## Shareholders report

# %%
response = ownership.insider.shareholders_report.Definition("TRI.N").get_data()

response.data.df
# Out:
#    instrument investorpermid           TR.InvestorFullName  \
# 0       TRI.N    34415094660               Binet (David W)
# 1       TRI.N    34413475330            Bello (Stephane O)
# 2       TRI.N    34413502693   Thomson (David Kenneth Roy)
# 3       TRI.N    34413475339            Opperman (Vance K)
# 4       TRI.N    34421551259        Kinnear (Anthony Paul)
# 5       TRI.N    34414034824        Clark (William Edmund)
# 6       TRI.N    34423299566         Friedenberg (Michael)
# 7       TRI.N    34413896392           Vuicic (Mary Alice)
# 8       TRI.N    34413502699                 Walker, Linda
# 9       TRI.N    34415147903  Marczewski (Piotr Wladyslaw)
# 10      TRI.N    34415161496            Beaumont (Stewart)
# 11      TRI.N    34417444091           Rushton (Charlotte)
# 12      TRI.N    34424828612      Eastwood (Michael Keith)
# 13      TRI.N    34425333595         Wong (David Franklin)
# 14      TRI.N    34415715941       Masterson (Neil Thomas)
# 15      TRI.N    34415640438             Kim (Thomas Sang)
# 16      TRI.N    34425347376          Beastrom (Elizabeth)
# 17      TRI.N    34415733097                Fischer (Paul)
# 18      TRI.N    34424894232                 Roth (Kirsty)
# 19      TRI.N    34425561658                 Hindt (David)
# 20      TRI.N    34413563880        Daniels (Michael Elie)
# 21      TRI.N    34424351015        O'Hagan (Heather Anne)
# 22      TRI.N    34417918265          Peccarelli (Brian S)
# 23      TRI.N    34419896182             Monaghan, Paula R
# 24      TRI.N    34418332742             Cannizzaro (Sean)
# 25      TRI.N    34415155456             Clamp-Held (Ruth)
# 26      TRI.N    34424514921            Ramseyer (Abigail)
# 27      TRI.N    34425333598               Pandita (Sunil)
# 28      TRI.N    34425428986           Kathryn (Ouellette)
#
#       TR.InvParentType      TR.InvestorType TR.InvestorRegion  \
# 0   Strategic Entities  Individual Investor     North America
# 1   Strategic Entities  Individual Investor     North America
# 2   Strategic Entities  Individual Investor     North America
# 3   Strategic Entities  Individual Investor     North America
# 4   Strategic Entities  Individual Investor    Asia / Pacific
# 5   Strategic Entities  Individual Investor     North America
# 6   Strategic Entities  Individual Investor     North America
# 7   Strategic Entities  Individual Investor     North America
# 8   Strategic Entities  Individual Investor
# 9   Strategic Entities  Individual Investor     North America
# 10  Strategic Entities  Individual Investor     North America
# 11  Strategic Entities  Individual Investor     North America
# 12  Strategic Entities  Individual Investor     North America
# 13  Strategic Entities  Individual Investor     North America
# 14  Strategic Entities  Individual Investor     North America
# 15  Strategic Entities  Individual Investor     North America
# 16  Strategic Entities  Individual Investor     North America
# 17  Strategic Entities  Individual Investor     North America
# 18  Strategic Entities  Individual Investor     North America
# 19  Strategic Entities  Individual Investor     North America
# 20  Strategic Entities  Individual Investor     North America
# 21  Strategic Entities  Individual Investor     North America
# 22  Strategic Entities  Individual Investor     North America
# 23  Strategic Entities  Individual Investor
# 24  Strategic Entities  Individual Investor     North America
# 25  Strategic Entities  Individual Investor     North America
# 26  Strategic Entities  Individual Investor     North America
# 27  Strategic Entities  Individual Investor     North America
# 28  Strategic Entities  Individual Investor     North America
#
#    TR.InvInvestmentStyleCode TR.InvInvmtOrientation TR.OwnTrnverRating  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7                                                                  MED
# 8
# 9
# 10
# 11                                                                 MED
# 12                                                                 MED
# 13                                                                HIGH
# 14
# 15
# 16                                                                HIGH
# 17                                                                HIGH
# 18                                                                HIGH
# 19
# 20                                                                 LOW
# 21                                                                 MED
# 22                                                                 MED
# 23
# 24                                                                 LOW
# 25                                                                 LOW
# 26                                                                 LOW
# 27                                                                HIGH
# 28
#
#     TR.OwnTurnover  ...  TR.SharesHeldChange  TR.SharesHeldValChg  \
# 0             <NA>  ...                    0                  0.0
# 1             <NA>  ...                15844           1388967.96
# 2             <NA>  ...                    0                  0.0
# 3             <NA>  ...                    0                  0.0
# 4             <NA>  ...                 2264            154400.97
# 5             <NA>  ...                    0                  0.0
# 6             <NA>  ...                 3115             273077.2
# 7          50.7341  ...                  259             24024.26
# 8             <NA>  ...                 5941            405166.14
# 9             <NA>  ...                    6               429.19
# 10            <NA>  ...                11031            967035.19
# 11         55.9416  ...                 3779            331286.92
# 12         50.1737  ...                  641             62059.34
# 13        245.1594  ...                 8532            997136.07
# 14            <NA>  ...               -15002           -1023111.0
# 15            <NA>  ...                 3095            350531.36
# 16        124.2408  ...                 3189            372698.89
# 17        123.8908  ...                  943            110208.55
# 18         173.514  ...                 3100            351097.65
# 19            <NA>  ...                 3222            298865.47
# 20          0.3076  ...                    0                  0.0
# 21         52.9199  ...                 1122             98360.39
# 22         75.5648  ...                    0                  0.0
# 23            <NA>  ...                   27              1931.33
# 24         17.1137  ...                   73              6399.56
# 25          8.5313  ...                  227             19900.01
# 26         18.3209  ...                   48              4452.37
# 27        675.2194  ...                  155             14377.45
# 28            <NA>  ...                   99               9835.3
#
#     TR.PctSharesOutHeldChange  TR.PctSharesHeldChangeOld  TR.PrevSharesHeld  \
# 0                       100.0                        0.0             261176
# 1                      110.81                      10.81             146564
# 2                       100.0                        0.0              50000
# 3                       100.0                        0.0              50000
# 4                      105.63                       6.44              35162
# 5                       100.0                        0.0              36316
# 6                      111.11                        9.9              31456
# 7                      101.59                       0.83              31253
# 8                       148.0                      48.13              12343
# 9                       100.0                       0.04              13604
# 10                       <NA>                        0.0               <NA>
# 11                     157.14                      52.93               7139
# 12                      105.0                       6.58               9745
# 13                       <NA>                        0.0               <NA>
# 14                      36.17                     -64.69              23191
# 15                     185.71                      93.45               3312
# 16                      275.0                     155.03               2057
# 17                      125.0                      23.98               3933
# 18                      300.0                     202.61               1530
# 19                       <NA>                        0.0               <NA>
# 20                      100.0                        0.0               2924
# 21                      200.0                      67.96               1651
# 22                      100.0                        0.0               2426
# 23                      125.0                       1.22               2212
# 24                     133.33                        4.3               1699
# 25                      100.0                      16.53               1373
# 26                      100.0                       8.65                555
# 27                       <NA>                        0.0               <NA>
# 28                       <NA>                        0.0               <NA>
#
#    TR.PrevPctOfSharesOutHeld TR.PrevSharesHeldValue  TR.PrevHoldingsDate  \
# 0                     0.0527            18372807.06           2020-04-07
# 1                     0.0296             9995416.69           2020-03-13
# 2                     0.0101              3517323.0           2020-04-07
# 3                     0.0101              3517323.0           2020-04-07
# 4                     0.0071             2515168.78           2019-12-16
# 5                     0.0073             2554702.04           2020-04-07
# 6                     0.0063             2574301.71           2020-12-10
# 7                     0.0063             2739801.54           2021-03-22
# 8                     0.0025              882905.64           2019-12-20
# 9                     0.0027              909913.29           2019-09-17
# 10                      <NA>                   <NA>                 <NA>
# 11                    0.0014               620368.4           2021-02-24
# 12                     0.002               854297.7           2021-03-23
# 13                      <NA>                   <NA>                 <NA>
# 14                    0.0047             1658872.62           2019-12-31
# 15                    0.0007              225872.79           2020-03-25
# 16                    0.0004              180327.38           2021-03-25
# 17                    0.0008              364816.23           2021-04-16
# 18                    0.0003              141919.36           2021-04-12
# 19                      <NA>                   <NA>                 <NA>
# 20                    0.0006              205693.05           2020-04-07
# 21                    0.0003              131718.04           2020-09-22
# 22                    0.0005              212675.86           2021-03-22
# 23                    0.0004               147951.2           2019-09-30
# 24                    0.0003              134534.66           2020-11-05
# 25                    0.0003               93636.28           2020-03-23
# 26                    0.0001                48654.2           2021-03-22
# 27                      <NA>                   <NA>                 <NA>
# 28                      <NA>                   <NA>                 <NA>
#
#                          TR.PrevFilingType  TR.InvAddrCountry
# 0                                 Proxy-CA             Canada
# 1                                     SEDI      United States
# 2                                 Proxy-CA             Canada
# 3                                 Proxy-CA      United States
# 4                                     SEDI          Australia
# 5                                 Proxy-CA             Canada
# 6                                     SEDI             Canada
# 7                                     SEDI             Canada
# 8                                     SEDI
# 9                                     SEDI             Canada
# 10                                                     Canada
# 11                                    SEDI             Canada
# 12                                    SEDI      United States
# 13                                                     Canada
# 14                                    SEDI             Canada
# 15                                    SEDI      United States
# 16  Canadian Insider - Initial Sedi Report             Canada
# 17                                    SEDI             Canada
# 18                                    SEDI             Canada
# 19                                                     Canada
# 20                                Proxy-CA      United States
# 21                                    SEDI             Canada
# 22                                    SEDI      United States
# 23                                    SEDI
# 24                                    SEDI             Canada
# 25                                    SEDI             Canada
# 26                                    SEDI             Canada
# 27                                                     Canada
# 28                                                     Canada
#
# [29 rows x 27 columns]

# %% [markdown]
# ## Transaction report

# %%
response = ownership.insider.transaction_report.Definition("TRI.N").get_data()

response.data.df
# Out:
#    instrument                    investorname                 date  \
# 0       TRI.N            Woodbridge Co., Ltd.  2021-09-23T00:00:00
# 1       TRI.N               Kim (Thomas Sang)  2021-09-17T00:00:00
# 2       TRI.N                   Roth (Kirsty)  2021-09-13T00:00:00
# 3       TRI.N            Peccarelli (Brian S)  2021-09-02T00:00:00
# 4       TRI.N           Wong (David Franklin)  2021-08-10T00:00:00
# ..        ...                             ...                  ...
# 95      TRI.N  Macintyre, Christopher Randall  2007-12-31T00:00:00
# 96      TRI.N          Naylor, Christine Lois  2007-12-31T00:00:00
# 97      TRI.N         Friedland, Edward Asher  2007-12-31T00:00:00
# 98      TRI.N            Zappa, Catherine Ann  2007-12-31T00:00:00
# 99      TRI.N                  Raffaeli, John  2007-12-31T00:00:00
#
#    TR.InsiderInvestorType                                     TR.InsiderRole  \
# 0         Holding Company                      10% Security Holder of Issuer
# 1     Individual Investor                           Senior Officer of Issuer
# 2     Individual Investor                           Senior Officer of Issuer
# 3     Individual Investor                                            Officer
# 4     Individual Investor                           Senior Officer of Issuer
# ..                    ...                                                ...
# 95    Individual Investor  Director or Senior Officer of Insider or Subsi...
# 96    Individual Investor  Director or Senior Officer of Insider or Subsi...
# 97    Individual Investor  Director or Senior Officer of Insider or Subsi...
# 98    Individual Investor  Director or Senior Officer of Insider or Subsi...
# 99    Individual Investor  Director or Senior Officer of Insider or Subsi...
#
#                                 TR.InsiderPrimaryRole TR.InsiderDate  \
# 0                                                <NA>     2007-04-27
# 1                            Senior Officer of Issuer     2019-08-13
# 2                            Senior Officer of Issuer     2020-08-24
# 3                                                <NA>           <NA>
# 4                            Senior Officer of Issuer     2020-06-29
# ..                                                ...            ...
# 95  Director or Senior Officer of Insider or Subsi...     2007-01-01
# 96  Director or Senior Officer of Insider or Subsi...     2007-01-01
# 97                           Senior Officer of Issuer           <NA>
# 98  Director or Senior Officer of Insider or Subsi...     2007-01-01
# 99                           Senior Officer of Issuer           <NA>
#
#     TR.InsiderIsNLE TR.InsiderIsNLEDate TR.InsiderInactiveDate  ...  \
# 0             False                None                   <NA>  ...
# 1             False                None                   <NA>  ...
# 2             False                None                   <NA>  ...
# 3             False                None                   <NA>  ...
# 4             False                None                   <NA>  ...
# ..              ...                 ...                    ...  ...
# 95            False                None                   <NA>  ...
# 96            False                None    2007-12-31T00:00:00  ...
# 97            False                None    2007-12-31T00:00:00  ...
# 98            False                None    2007-12-31T00:00:00  ...
# 99            False                None    2007-12-31T00:00:00  ...
#
#     TR.AsRepSharesHeld TR.AsRepIndSharesHeld TR.InsiderRegion  \
# 0            326185829                  None    North America
# 1                 6407                  None    North America
# 2                 4630                  None    North America
# 3                 <NA>                  None    North America
# 4                 8532                  None    North America
# ..                 ...                   ...              ...
# 95                1315                  None    North America
# 96                 799                  None
# 97                 414                  None
# 98                  18                  None
# 99                4594                  None
#
#              TR.InsAddressLine1 TR.InsAddressLine2 TR.InsAddressLine3  \
# 0   65 Queen Street West - 2400
# 1
# 2
# 3
# 4
# ..                          ...                ...                ...
# 95
# 96
# 97
# 98
# 99
#
#     TR.InsStateProv  TR.InsAddressCity  TR.InsCountry  TR.InsPostalCode
# 0                              Toronto                          M5H 2M8
# 1
# 2
# 3
# 4
# ..              ...                ...            ...               ...
# 95
# 96
# 97
# 98
# 99
#
# [100 rows x 44 columns]

# %% [markdown]
# # Org-info

# %%
response = ownership.org_info.Definition("TRI.N").get_data()

response.data.df
# Out:
#   instrument         TR.CommonName                TR.ExchangeName  \
# 0      TRI.N  Thomson Reuters Corp  NEW YORK STOCK EXCHANGE, INC.
#
#                         TR.OrgTRBCActivity TR.TRBCActivityCode  \
# 0  Professional Information Services (NEC)          5220307010
#
#   TR.HQCountryCode TR.HeadquartersCountry TR.FreeFloat TR.FreeFloatPct  \
# 0               CA                 Canada    165400260         33.3568
#
#   TR.SharesOutstanding TR.SharesHeldByStrategicInvestors  \
# 0            495851072                         330450812
#
#   Strategic Entities Ownership% Market Capitalization
# 0              66.6431577261973      55284.3650870792

# %% [markdown]
# ### Close the session

# %%
rd.close_session()
# Out:
# [2021-09-29 15:29:53,446] - [INFO] - [sessions.platform.default-session.0] - [17696] | MainThread
# Closing session
# [2021-09-29 15:29:54,238] - [INFO] - [sessions.platform.default-session.0] - [17696] | MainThread
# Session is closed
