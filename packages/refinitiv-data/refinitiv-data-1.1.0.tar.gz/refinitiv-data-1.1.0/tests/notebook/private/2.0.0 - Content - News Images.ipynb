# %%
import refinitiv.data as rd

# %%
from refinitiv.data.content import news

# %%
rd.open_session("platform.default")
# Out:
# <refinitiv.data.session.Definition object at 0x188a5165730 {name='default'}>

# %%
definition = news.images.Definition("22T112537Z_1_MQ4_RTRLXPP_2_LYNXPACKAGER__JPG")
response = definition.get_data()

# %%
image = response.data.image

# %%
image.show()

# %%
image.filename
# Out:
# '2022-11-22T112537Z_1_MQ4_RTRLXPP_2_LYNXPACKAGER.JPG'

# %%
image.size
# Out:
# 38174

# %%
image.body_type
# Out:
# ['image/jpeg']

# %%
image.provider
# Out:
# ['NOT AVAILABLE']

# %%
image.source
# Out:
# ['RTRS']

# %%
image.version_created
# Out:
# ['20221122T112537.110+0000']

# %%
image.first_created
# Out:
# ['20221122T112537.110+0000']

# %%
image.available_rsf
# Out:
# ['No']

# %%
image.body_type
# Out:
# ['image/jpeg']

# %%
image.save(path='images/')

# %% [markdown]
# ## width/height parameters

# %%
definition = news.images.Definition("22T112537Z_1_MQ4_RTRLXPP_2_LYNXPACKAGER__JPG", width=200)
response = definition.get_data()

# %%
image = response.data.image

# %%
image.show()

# %%
image.filename
# Out:
# '22T112537Z_1_MQ4_RTRLXPP_2_LYNXPACKAGER_.JPG'

# %%
image.size
# Out:
# 6373

# %%
image.body_type

# %%
image.provider

# %%
image.source

# %%
image.version_created

# %%
image.first_created

# %%
image.available_rsf

# %%
image.body_type
